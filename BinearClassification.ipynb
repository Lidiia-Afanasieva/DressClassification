# %% [markdown]
# <a href="https://colab.research.google.com/github/Lidiia-Afanasieva/DressClassification/blob/master/BinearClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from PIL import Image
import os
import seaborn as sns


# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
# uploaded = files.upload()
img = plt.imread('/content/2_100.jpg')
plt.imshow(img)

# %%
os.chdir("/content/drive/MyDrive/Training-Pineapple")
# !ls

# %%
# f = open('/content/drive/MyDrive/Training-Pineapple', '')
# f.read()
# pat = '/content/drive/MyDrive/Training-Pineapple'
files = []
for i in range(1):
    files=[i for i in os.listdir() if os.path.isfile(i)]
    print(files)
    # Get the MD5 hash for each -- use a for loop to process each file
    # for file_name in files:

for i, j in enumerate(files[:100]):
    img = plt.imread('/content/drive/MyDrive/Training-Pineapple/' + j)
    plt.subplot(10,10,i+1)
    # plt.figure(figsize=(50,50))/
    plt.title(j.split('.')[0])
    plt.axis('off')
    plt.imshow(img)

# %%
train_prickle_dir = "/content/drive/MyDrive/Training-Pineapple"
train_huck_dir = "/content/drive/MyDrive/Training-Huckleberry"
test_prickle_dir = "/content/drive/MyDrive/Test-Pineapple"
test_huck_dir = "/content/drive/MyDrive/Test-Huckleberry"

directory = [train_prickle_dir, train_huck_dir, test_prickle_dir, test_huck_dir]
classes = ['Blue_one', 'Prickly_one']
img_size = 100
train_ararys = []
test_ararys = []

for i in classes:
    for k in range(4):
        path  = os.path.join(directory[k], i)  # its return a fucking string with path and class type
        for img in os.listdir(path):
            img_arr =  cv2.imread(os.path.join(path, img))
            img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BRG2RGB)
            if i == 0:
                train_ararys.append([img_arr, i])
            else:
                test_ararys.append([img_arr, i])

only_img_list = []
for image, c_count in train_ararys:
    only_img_list.append(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-e0d15eb265bb> in <module>()
#      13     for k in range(4):
#      14         path  = os.path.join(directory[k], i)  # its return a fucking string with path and class type
# ---> 15         for img in os.listdir(path):
#      16             img_arr =  cv2.imread(os.path.join(path, img))
#      17             img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BRG2RGB)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Training-Pineapple/Blue_one'
